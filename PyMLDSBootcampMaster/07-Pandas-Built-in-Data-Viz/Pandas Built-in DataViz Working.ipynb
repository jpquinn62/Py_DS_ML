# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)

# %%
df1.head() # dataset is a time series as col 0 is date
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1['A'].hist() # straight plot col a as a histogram, with pandas, note its calling matplotlib in output

# %%
df1['A'].hist(bins=30)  # can add matplotlib or seaborn args

# %%
import seaborn as sns # make things look nicer call in this lib, then... run same cells, will look like seaborn plot

# %%
# but add up at top and rerun the plots, they will look nicer

# %%
df1['A'].plot(kind='hist') # diff way to call, use .plot ,etc ...

# %%
df1['A'].plot(kind='hist',bins=30) # add args

# %%
df1['A'].plot.hist() # can call directly like this too

# %%
df1['A'].plot.hist(bins=30) # add args

# %%
df2.head() # non time series , has norm index
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# Area Plots

# %%
df2.plot.area() # area plot type

# %%
df2.plot.area(alpha=0.4) # add alpha for more transparency

# %%
# Bar Plots

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
df1['A'].plot.hist(bins=50) # histograms are used the most quite often

# %%
df1.head() # time series,
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
# line plot

# %%
df1.plot.line(y='B')  # leave this out for now:  x=df1.index,

# %%
df1.plot.line(y='B',figsize=(12,3),lw=1) # add matplotlib args

# %%
# scatter plots

# %%
df1.plot.scatter(x='A',y='B') # shit+tab to get kwargs

# %%
df1.plot.scatter(x='A',y='B',c='C') # add c is for color and here based off another column

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm') # pass in a color map # 3d levls of data, a 3d plot iow's

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']) # instead of color as arg, use size, but it's too small, see below
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py:857: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100) # add multiply factor to scale up points

# %%
# Boxplots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.box()

# %%
# Bi-Varient data or two variables, in this case A and B

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0 -1.373796  0.388668
# 1  0.391775 -0.054717
# 2  1.320489  0.409949
# 3 -0.281032 -1.821416
# 4  0.207751  1.083965

# %%
df.plot.hexbin(x='a',y='b') # he plot with hex bins

# %%
df.plot.hexbin(x='a',y='b',gridsize=25) # enhance grid size to scale it up

# %%
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='coolwarm') # add colormapping

# %%
# kde kernel desity estimation plots, in place of a histogram instead

# %%
df2['a'].plot.kde()

# %%
df2['a'].plot.density() # this density is same as kde plot

# %%
df2.plot.density() # can do off entie df, not just one col

# %%
df2.plot.kde()
