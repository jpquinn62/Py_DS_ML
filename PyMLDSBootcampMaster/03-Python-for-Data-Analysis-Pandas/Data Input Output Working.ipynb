# %%
import numpy as np
import pandas as pd

# %%
# CSV input

# %%
pwd
# Out:
# '/Users/jpquinn/Documents/Udemy Machine Learning and Data Science/Py ML DS Bootcamp Master/Refactored_Py_DS_ML_Bootcamp-master/03-Python-for-Data-Analysis-Pandas'

# %%
# open and read CSV files

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv('example')    # save to a var

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output',index=False) # adding false will make it not add a bad old index column and goof the structure

# %%
pd.read_csv('My_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
# reading and writing with Excel files

# %%
pd.read_excel('Excel_Sample.xlsx' ,sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
# Write pandas df to a excel file

# %%
df.to_excel('Excel_Sample2.xlsx',sheet_name='NewSheet')

# %%
#HTML Input

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
type(df)
# Out:
# list

# %%
df[0]  #.head() # lsit the top head of the df of first 5
# Out:
#                              Bank Name           City  ST   CERT  \
# 0                 The First State Bank  Barboursville  WV  14361
# 1                   Ericson State Bank        Ericson  NE  18265
# 2     City National Bank of New Jersey         Newark  NJ  21111
# 3                        Resolute Bank         Maumee  OH  58317
# 4                Louisa Community Bank         Louisa  KY  58112
# ..                                 ...            ...  ..    ...
# 556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557                Malta National Bank          Malta  OH   6629
# 558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559  National State Bank of Metropolis     Metropolis  IL   3815
# 560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# 0                         MVB Bank, Inc.      April 3, 2020
# 1             Farmers and Merchants Bank  February 14, 2020
# ...

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
# df.to_sql('my_table',engine) # note, had to change and add [0] like getting the list up above
df[0].to_sql('my_table',engine)

# %%
# to read the table, first setup.... make it a var that holds the list of table data in pandas

# %%
sqldf = pd.read_sql('my_table', con=engine) # then read with below

# %%
sqldf
# Out:
#      index                          Bank Name           City  ST   CERT  \
# 0        0               The First State Bank  Barboursville  WV  14361
# 1        1                 Ericson State Bank        Ericson  NE  18265
# 2        2   City National Bank of New Jersey         Newark  NJ  21111
# 3        3                      Resolute Bank         Maumee  OH  58317
# 4        4              Louisa Community Bank         Louisa  KY  58112
# ..     ...                                ...            ...  ..    ...
# 556    556                 Superior Bank, FSB       Hinsdale  IL  32646
# 557    557                Malta National Bank          Malta  OH   6629
# 558    558    First Alliance Bank & Trust Co.     Manchester  NH  34264
# 559    559  National State Bank of Metropolis     Metropolis  IL   3815
# 560    560                   Bank of Honolulu       Honolulu  HI  21029
#
#                    Acquiring Institution       Closing Date
# ...

# %%
type(sqldf)
# Out:
# pandas.core.frame.DataFrame
